# %%
from scipy.stats import uniform

# %%
uniform.rvs(scale = 10, size = 10)
# Out:
# array([5.01442394, 2.02685359, 7.47074674, 2.07693974, 8.9102815 ,
#        3.82865812, 8.83211683, 4.64466786, 4.61210633, 1.66230368])

# %%
def myRandomGenerator(x, p, size=1):
    lista = []
    for _ in range(size):
        Y = uniform.rvs(loc=0, scale=1)
        sum = 0
        for i in range(len(p)):
            if sum <= Y <= sum + p[i]:
                X = x[i]
            sum += p[i]
        lista.append(X)
        
    return lista

# %%
myRandomGenerator([0, 1, 2], [1/3, 1/6, 1/2], 10)
# Out:
# [2, 2, 2, 0, 2, 1, 0, 0, 0, 0]

# %%
from random import randrange
from matplotlib.pyplot import bar, hist, grid, show, legend

# %%
x_vals = [1, 2, 3]
p_vals = [1/3, 1/6, 1/2]

samples = myRandomGenerator(x_vals, p_vals, size=100)
bin_edges = [ 0.5, 1.5, 2.5, 3.5 ]

hist(samples, bins=bin_edges, density=True, edgecolor='black', label="Histogram", color = 'yellow')
distribution = {1:1/3, 2:1/6, 3:1/2}
bar(distribution.keys(), distribution.values(), width = 0.8, color = 'red', edgecolor = 'black', alpha = 0.6)

grid()
show()

# %%
from math import log

def myRandomGenerator2(alpha, size=1):
    lista = []
    for _ in range(size):
        Y = uniform.rvs()
        X = -1/alpha * log(1 - Y)
        lista.append(X)
    return lista

# %%
print(myRandomGenerator2(1, 10))
# Out:
# [1.4577950144254281, 0.9962535122931027, 0.3949065822466588, 1.6387874828880078, 0.21744758624502186, 0.13669297180188408, 2.9350019912996537, 0.38315885672588573, 1.2045442540672435, 3.6786684532058964]

# %%
from matplotlib.pyplot import show, hist, grid, legend, xticks, plot
from scipy.stats import expon

alpha = 1 / 12
data = myRandomGenerator2(alpha, 1000)
hist(data, bins=12, density = True, range=(0,61))
x = range(60)
plot(x,expon.pdf(x,loc=0,scale=1/alpha),'r-')
xticks(range(0,60,5))
grid()
show()
